# %% [markdown]
# # Segmentation Kraken + TrOCR
#
# Ce notebook exécute le pipeline complet sur une page complète issue de `CATMuS/medieval-segmentation` : segmentation Kraken, extraction des lignes, export PAGE XML, puis transcription TrOCR optionnelle.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.segmentation.kraken_segmentation import segment_page

summary = segment_page(str(PROJECT_ROOT / 'config.yaml'))
summary

# %%
from IPython.display import Image, display

display(Image(filename=summary['annotated']))

# %%
import json

with open(summary['transcriptions'], encoding='utf-8') as handle:
    lines = json.load(handle)

for line in lines[:5]:
    print(line.get('id'), line.get('prediction', ''))
